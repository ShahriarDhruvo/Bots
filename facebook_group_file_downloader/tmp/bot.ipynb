# %%
############### Acknowledgement ###############
# set your browser download location to your desire location because all files will be downloaded to the download location setted in your browser.

# Thanks -> pythonjar, MariyaSha and some other stackoverflow members...

# %%
import os
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
# disable all alerts from facebook while scrapping
options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
options.add_experimental_option("prefs",prefs)

#############################################################################
# specify the path to chromedriver.exe (download and save on your computer) #
#############################################################################

############################## WINDOWS ######################################
# service = Service('C:/Users/shahr/chromedriver.exe')                      #
# driver = webdriver.Chrome(service=service, options=options)               #
#############################################################################

############################## LINUX ########################################
# driver = webdriver.Chrome('chromedriver', options=options) # linux        #
#############################################################################
service = Service('C:/Users/shahr/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

# for obvious reason 😁
with open('.secret', encoding='utf-8') as f:
    secrets = [line.strip() for line in f.readlines()] # 0 -> username, 1 -> password, 2 -> download directory (for checking)

# %%
# open the webpage
driver.get("http://www.facebook.com")

# target credentials
username = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='email']")))
password = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='pass']")))

# enter username and password
username.clear()
username.send_keys(secrets[0])
password.clear()
password.send_keys(secrets[1])

# target thesrc login button and click it
button = WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button[type='submit']"))).click()

###############################################################################################################################
# It should be logged in! -> if you have 2fa then you have to authorize it manually and then run the remaining cells manually #
###############################################################################################################################

# %%
log_file_location = 'bot.log'

#########################################################
# sleep is important because if we scrape too fast then #
# facebook will detect the bot and block this account   #
#########################################################
def waitNSeconds(sleep_time = 1):
    time.sleep(sleep_time)

def writeToFile(text):
    with open(log_file_location, 'a', encoding='utf-8') as f:
        f.write(text + "\n")

###################################################################
# scroll down to load more files                                  #
# wait 60s before determining that there is no more files to load #
###################################################################
def loadMoreFiles(files_to_load, identifier, timeout = 60, n_scroll = 1):
    for _ in range(n_scroll): # scroll for n times
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        seconds = 0
        current_len = len(files_to_load)

        while (current_len >= len(files_to_load)) and seconds < timeout:
            time.sleep(1.5) # wait every 1.5s before checking again -> because 1s is too fast :V

            files_to_load.extend([
                element for element in driver.find_elements(
                    By.XPATH, identifier
                ) if element not in files_to_load
            ])

            seconds += 1.5
        
    return files_to_load

def waitToFinishDownload(directory, timeout, nfiles=None):
    """
    Wait for downloads to finish with a specified timeout.

    Args
    ----
    directory : str
        The path to the folder where the files will be downloaded.
    timeout : int
        How many seconds until it stops waiting.
    nfiles : int, defaults to None
        If provided, also wait for the expected number of files.

    """
    
    print("\nWaiting for {} files to be downloaded\n".format(nfiles))

    seconds = 0
    dl_wait = True

    while dl_wait and seconds < timeout:
        time.sleep(0.5) # check every 0.5s
        dl_wait = False
        files = os.listdir(directory)
        
        # if nfiles and len(files) != nfiles:
        # if nfiles and len(files) < nfiles:
        #     dl_wait = True

        for fname in files:
            if fname.endswith('.crdownload'): # as partial downloaded files will be of ".crdownload" extension for chromium based browsers
                dl_wait = True
                break

        seconds += 0.5
    
    if seconds >= timeout:
        seconds = -1
        print("Your connection is too slow or you are not connected! Try again later. Closing the connection...")
    else:
        print("Continuing after {}s...\n".format(seconds))

    return seconds

# Resume from last downloaded file
def checkDownloadHistory(directory, files_in_directory):
    with open(directory, 'r', encoding='utf-8') as f:
        total_lines = files_in_directory
        file_entries = f.readlines()

        while total_lines:
            total_lines -= 1

            try:
                last_entry = file_entries[total_lines]
                last_entry = str(last_entry).split(' --- ')

                # [1:-1] is to strip out the single quote & strip() for extra spaces
                last_file_name = last_entry[0].strip()[1:-1]
                last_file_date = last_entry[2].strip()[1:-1]

                print("Download history: Found. Download will resume from '{}' file".format(last_file_name))
                
                return last_file_name, last_file_date
            except:
                last_file_name = False

    if not last_file_name: print("Download history: Not Found")

    return False, False

# %%
# waitNSeconds(5) # enable this if this script is fully automated for your case
driver.get("https://www.facebook.com/groups/201623576939858/files/")

download_thread_count = 3 # this value will ensure how many downloads will happen concurrently

# to wait until the element is ready -> Explicit Waits
wait = WebDriverWait(driver, 10)

##################################################################################
# targets identifiers                                                            #
# this identifiers will change continuously so update it according to your needs #
##################################################################################
fileOption_xpath = "//div[@aria-label='File options']" # find 15 per-scroll
fileName_xpath = "//span[@class='d2edcug0 hpfvmrgz qv66sw1b c1et5uql lr9zc1uh a8c37x1j fe6kdd0r mau55g9w c8b282yb keod5gw0 nxhoafnm aigsh9s9 d3f4x2em iv3no6db jq4qci2q a3bd9o3v lrazzd5p oo9gr5id hzawbc8m']" # find 15 per-scroll
fileTypeDate_xpath = "//span[@class='d2edcug0 hpfvmrgz qv66sw1b c1et5uql lr9zc1uh a8c37x1j fe6kdd0r mau55g9w c8b282yb keod5gw0 nxhoafnm aigsh9s9 d9wwppkn iv3no6db e9vueds3 j5wam9gi b1v8xokw oo9gr5id hzawbc8m']" # find 30 per-scroll
# sortButtons_xpath = "//div[@class='l9j0dhe7 du4w35lb j83agx80 pfnyh3mw taijpn5t bp9cbjyn owycx6da btwxx1t3 kt9q3ron ak7q8e6j isp2s0ed ri5dt5u2 rt8b4zig n8ej3o3l agehan2d sk4xxmp2 rq0escxv d1544ag0 tw6a2znq tdjehn4e tv7at329']" # find 3 per-scroll

#########################################################################
# as it doesn't sort by file type reliably 😑
# sortButtons = wait.until(
#     EC.presence_of_all_elements_located((By.XPATH, sortButtons_xpath))
# )

# # sort by file_type (PDF at the top in my case)
# driver.execute_script("arguments[0].click();", sortButtons[1])
#########################################################################

# %%
# initial target search
file_option_buttons = wait.until(
    EC.presence_of_all_elements_located((By.XPATH, fileOption_xpath))
)
file_names = wait.until(
    EC.presence_of_all_elements_located((By.XPATH, fileName_xpath))
)
file_types_and_dates = wait.until(
    EC.presence_of_all_elements_located((By.XPATH, fileTypeDate_xpath))
)

j, k = 0, 1
registered_files_count = sum(1 for line in open(log_file_location, encoding='utf-8')) # total files registered in the log file
resume_download = not registered_files_count # if there is log then download will not resume without checking

# Resume from last downloaded file
if registered_files_count:
    last_file_name, last_file_date = checkDownloadHistory(log_file_location, registered_files_count)

for idx, button in enumerate(file_option_buttons):
    try:
        _name = file_names[idx].text
        _type = file_types_and_dates[j].text
        _date = file_types_and_dates[k].text

        # as file_types_and_dates contains both type and date
        j += 2; k += 2

        # scroll after 15th button click to load more files (as 15 files load per scroll)
        if (idx + 1) % 15 == 0:
            file_option_buttons = loadMoreFiles(file_option_buttons, fileOption_xpath)

            file_names.extend([
                name for name in driver.find_elements(
                    By.XPATH, fileName_xpath
                ) if name not in file_names
            ])

            file_types_and_dates.extend([
                type_date for type_date in driver.find_elements(
                    By.XPATH, fileTypeDate_xpath
                ) if type_date not in file_types_and_dates
            ])

        ######################################################################################################################
        # download pdf files only                                                                                            #
        # cannot check it before the scroll because there is a possibility to have more than one page worth of non-pdf files #
        ######################################################################################################################
        if not _type == "PDF": continue

        #################################################################################################################
        # to skip already downloaded files                                                                              #
        # if first check is False then others will not be checked so you don't have to ->                               #
        # worry about having last_file_name, last_file_date being initialized because of resume_download check at first #
        #################################################################################################################
        if not resume_download and last_file_name and _name == last_file_name and _date == last_file_date:
            print("Resuming...\n")
            resume_download = True
            continue # for skipping the last entry too

        if not resume_download:
            print("Skipping... {}/{} ---> {}".format(idx+1, len(file_option_buttons), _name))
            continue
        
        ##########################################################################################################
        # waiting after every 3 donwloads                                                                        #
        # we have to wait for the files to be downloaded, if we continue without it there maybe some files       #
        # that couldn't be downloaded on time (before the link expire) and later on those files can't be resumed #
        ##########################################################################################################
        if (idx + 1) % download_thread_count == 0:
            download_time = waitToFinishDownload(secrets[2], 600, registered_files_count) # waiting for 600s before closing the connection for slow/no internet

            if download_time == -1: break # stoping the scrapper incase of network failure

        ###################################### download script starts ######################################

        driver.execute_script("arguments[0].click();", button)
        # wait.until(EC.element_to_be_clickable(button)).click() # this was giving me -> ElementClickInterceptedException

        waitNSeconds(0.8)

        try:
            download_link = wait.until(
                EC.presence_of_element_located((By.CSS_SELECTOR, "a[href*='https://www.facebook.com/download/']"))
            )
            driver.execute_script("arguments[0].target='_self';", download_link) # to prevent it from opening into a new tab
            driver.execute_script("arguments[0].click();", download_link)
            
            registered_files_count += 1 # keeping track of downloaded files

        except:
            writeToFile("***** Warning: No download link found at {} *****".format(idx+1))
            
        ###################################### download script finished ###################################

        # updating log
        log = '"{}" --- "{}" --- "{}"'.format(_name, _type, _date)
        writeToFile(log)

        print("{} --- {} - {}".format(_name, _date, len(file_option_buttons)))

        #################################################################
        # waiting at least 2s for safety sake 😅                        #
        # waiting (1.2+0.8+calculation_time) -> 2s+ after each download #
        #################################################################
        waitNSeconds(1.2)

    except Exception as e:
        log = "***** ERROR at {}, date: {}: {} *****".format(idx+1, _date, e)
        
        print(log)
        writeToFile(log)

# driver.close() # not closing because I had to run this cell multiple times during test
print("\nCompleted. Total scrapped file:", registered_files_count)
# Out:
# Download history: Found. Download will resume from 'আনন্দমেলা ১৮১১৮১.pdf' file
# Skipping... 1/15 ---> জলছবি - সুচিত্রা ভট্টাচার্য.pdf
# Skipping... 2/15 ---> বেগম আখতার.pdf
# Skipping... 3/15 ---> রামানুজের জ্যোতির্বলয় – উৎপল মুখোপাধ্যায়.pdf
# Skipping... 4/15 ---> আয়নামহল - সুচিত্রা ভট্টাচার্য.pdf
# Skipping... 5/15 ---> অনেক বেবুন - অমিয়ভূষণ মজুমদার.pdf
# Skipping... 6/15 ---> ৩০০ বছরের কলকাতা পটভূমি ও ইতিকথা - ডঃ অতুল সুর .pdf
# Skipping... 85/90 ---> তুলতুল.pdf
# Skipping... 86/90 ---> মুশকিল আসান.pdf
# Skipping... 87/90 ---> শিব্রাম সংগ্রহ ২.pdf
# Skipping... 88/90 ---> শিব্রাম সংগ্রহ ১.pdf
# Skipping... 89/90 ---> চার্লস ডারউইন ও প্রজাতির উৎপত্তি.pdf
# Skipping... 90/105 ---> পাণিনি সার - নবচন্দ্র ন্যায়রত্ন.pdf
# Skipping... 91/105 ---> বইমেলা পুস্তক তালিকা অভিযান.pdf
# Skipping... 92/105 ---> উপনিষদের কথা.pdf
# Skipping... 93/105 ---> ননী ভৌমিক অনুবাদে মৌলিকতায়.pdf
# Skipping... 94/105 ---> একটি তুলসী গাছের কাহিনী.pdf
# Skipping... 95/105 ---> হাড় - নারায়ণ গঙ্গোপাধ্যায়.pdf
# Skipping... 96/105 ---> ekhane okon mapa hoy @ boibilas.pdf
# Skipping... 97/105 ---> আমার বন্ধু রাশেদ.pdf
# Skipping... 98/105 ---> স্বতন্ত্র ভাবনা.pdf
# Skipping... 99/105 ---> আনন্দমেলা২০০২২২.pdf
# Skipping... 100/105 ---> রবিবারোয়ারি২৭০২২২.pdf
# Skipping... 101/105 ---> ওমেগা পয়েন্ট.pdf
# Skipping... 102/105 ---> বৃষ্টি ও মেঘমালা.pdf
# Skipping... 103/105 ---> সাহিত্যের সেরা গল্প শরৎচন্দ্র চট্টোপাধ্যায়.pdf
# Skipping... 104/105 ---> নিষ্ফলা মাঠের কৃষক: আবদুল্লাহ আবু সাইদdownloadfile-424.pdf
# Skipping... 105/135 ---> ওড_উড__র দ_ন - আবদ_ল_ল_হ আব_ স_য__দ.pdf
# Skipping... 106/135 ---> মনে পড়ে - তপন সিংহ .pdf
# Skipping... 107/135 ---> বৈষ্ণব পদাবলী – সুনীতিকুমার চট্টোপাধ্যায়.pdf
# Skipping... 108/135 ---> বৈদিক সমাজে সংঘ বোধ – নৃপেন্দ্র গোস্বামী.pdf
# Skipping... 109/135 ---> বনফুলের আরও গল্প - বলাইচাঁদ মুখোপাধ্যায়.pdf
# Skipping... 110/135 ---> মহাকবি চাঁদ বরদাই – অমিয়কুমার সেন.pdf
# Skipping... 111/135 ---> এরিস্টটল এর পলিটিক্স - সরদার ফজলুল করিম.pdf
# Skipping... 114/135 ---> স্বাস্থ্য সমাচার (১৬ বর্ষ) ১৩৩৪ (১৯২৭).pdf
# Skipping... 115/135 ---> স্বাস্থ্য সমাচার (অষ্টম বর্ষ) ১৩২৬ (১৯১৯).pdf
# Skipping... 116/135 ---> স্বাস্থ্য সমাচার (নবম বর্ষ) ১৩২৭ (১৯২০).pdf
# Skipping... 117/135 ---> স্বাস্থ্য সমাচার (সপ্তম বর্ষ) ১৩২৫ (১৯১৮).pdf
# Skipping... 118/135 ---> স্বাস্থ্য সমাচার (দ্বিতীয় বর্ষ) ১৩২০ (১৯১৩).pdf
# Skipping... 119/135 ---> স্বনির্বাচিত নাট্যসংগ্রহ - বাদল সরকার.pdf
# Skipping... 151/180 ---> প্রসাদ প্রসঙ্গ - এস.ঘোষ.pdf
# Skipping... 152/180 ---> রচনাঞ্জলি - সুরেন্দ্রপ্রসাদ নিয়োগী.pdf
# Skipping... 153/180 ---> ভাষা শিক্ষা ককবরক - নির্মলেন্দু আচার্য্য.pdf
# Skipping... 154/180 ---> মিথ্যার জয় ও আরো কয়েকটি ছোট গল্প - সত্যরঞ্জন সেন.pdf
# Skipping... 155/180 ---> রবীন্দ্র-কাব্যভাষা - সুনন্দা দত্ত.pdf
# Skipping... 156/180 ---> শ্রীশ্রীমা ও সপ্তসাধিকা.pdf
# Skipping... 157/180 ---> হানা বাড়ী – প্রতিমা গঙ্গোপাধ্যায়.pdf
# Skipping... 158/180 ---> সোভিয়েত দেশের ইতিহাস.pdf
# Skipping... 159/180 ---> কঞ্জুস - সুমন্ত আসলাম.pdf
# Skipping... 160/180 ---> উত্তাপ – শঙ্কর গুপ্ত.pdf
# Skipping... 161/180 ---> সোভিয়েত রাশিয়ায় শিক্ষা ব্যবস্থা - অনিল কুমার সিংহ অনুদিত.pdf
# Skipping... 162/180 ---> সোভিয়েত সভ্যতা (১ম পর্ব) - বিনয় ঘোষ.pdf
# Skipping... 163/180 ---> মেঘের কোলে রোদ - কাসেম বিন আবুবাকার.pdf
# Skipping... 164/180 ---> ক্রন্দসী প্রিয় - কাসেম বিন আবুবাকার.pdf
# Skipping... 165/195 ---> পাহাড়ী ললনা - কাশেম বিন আবুবাকার.pdf
# Skipping... 166/195 ---> ফুটন্ত গোলাপ - কাসেম বিন আবুবাকার.pdf
# Skipping... 167/195 ---> বিদেশি মেম - কাসেম বিন আবুবাকার.pdf
# Skipping... 168/195 ---> বাসর রাত- কাশেম বিন আবুবাকার.pdf
# Skipping... 169/195 ---> প্রেম - কাশেম বিন আবুবাকার.pdf
# Skipping... 170/195 ---> আজকের রাশিয়া.pdf
# Skipping... 171/195 ---> কি পেলাম - কাসেম বিন আবুবাকার.pdf
# Skipping... 172/195 ---> কাঙ্ক্ষিত জীবন - কাসেম বিন আবুবাকার.pdf
# Skipping... 173/195 ---> যুগান্তর ঈদ সংখ্যা ২০১৯.pdf
# Skipping... 174/195 ---> জানি না কখন - সুমন্ত আসলাম.pdf
# Skipping... 175/195 ---> কেবলই - সুমন্ত আসলাম.pdf
# Skipping... 176/195 ---> অলৌকিক প্রেম - কাশেম বিন আবুবাকার.pdf
# Skipping... 177/195 ---> অবাঞ্ছিত উইল - কাসেম বিন আবুবাকার.pdf
# Skipping... 178/195 ---> অথচ আজ বসন্ত - সুমন্ত আসলাম.pdf
# Skipping... 179/195 ---> অগ্নিমানুষ - সুমন্ত আসলাম.pdf
# Skipping... 180/210 ---> সুনীলের সেরা ১০১ - সুনীল গঙ্গোপাধ্যায়.pdf
# Skipping... 181/210 ---> নটীর অভিশাপ.pdf
# Skipping... 182/210 ---> চেতনার অন্বেষণে০২২২.pdf
# Skipping... 183/210 ---> Hindu Somajer Goron.pdf
# Skipping... 184/210 ---> নদী - বনফুল (বলাইচাঁদ মুখোপাধ্যায়).pdf
# Skipping... 185/210 ---> নতুন নতুন নাটক - সম্পাদনা - মনোজ মিত্র.pdf
# Skipping... 186/210 ---> ময়ূর সিংহাসন.pdf
# Skipping... 187/210 ---> দশটি উপন্যাস - সৈয়দ মুস্তাফা সিরাজ.pdf
# Skipping... 188/210 ---> নানা রসের নয়টি উপন্যাস - মহাশ্বেতা দেবী.pdf
# Skipping... 189/210 ---> সন্ধ্যা মুখোপাধ্যায় শ্রদ্ধাঞ্জলি আনন্দবাজার পত্রিকা, এই সময় পত্রিকা.pdf
# Skipping... 190/210 ---> গিরিগুহার রহস্য.pdf
# Skipping... 191/210 ---> প্রাণ নিয়ে খেলা.pdf
# Skipping... 192/210 ---> অদৃশ্য বিচারক.pdf
# Skipping... 193/210 ---> বাঘের চেয়েও ভয়ানক.pdf
# Skipping... 194/210 ---> পিতৃধন.pdf
# Skipping... 195/225 ---> চিতে ডাকাত.pdf
# Skipping... 196/225 ---> বিশ্বম্ভরবাবুর বাঘ শিকার.pdf
# Skipping... 197/225 ---> নিজের হাতে.pdf
# Skipping... 198/225 ---> সববোনাশ.pdf
# Skipping... 199/225 ---> সেই লোকটা.pdf
# Skipping... 200/225 ---> হনোলুলুর মাকুদা.pdf
# Skipping... 201/225 ---> প্রথম পুরষ্কার.pdf
# Skipping... 202/225 ---> অন্য গ্রহের আমি.pdf
# Skipping... 203/225 ---> বৃষ্টির পর রোদ্দুর.pdf
# Skipping... 204/225 ---> ড্রাগন ফ্লাই.pdf
# Skipping... 205/225 ---> রাজার রাজা.pdf
# Skipping... 206/225 ---> অলক্ষ্মীর গয়না - সৈয়দ মুস্তাফা সিরাজ.pdf
# Skipping... 207/225 ---> আশাপূর্ণা দেবীর গ্রন্থাবলী - আশাপূর্ণা দেবী.pdf
# Skipping... 208/225 ---> ভুতোর ডাইরি.pdf
# Skipping... 209/225 ---> প্রেত – সমীর চট্টোপাধ্যায়.pdf
# Skipping... 210/240 ---> বাংলাদেশে সমাজতন্ত্রের চেতনা ও - হাসানুজ্জামান.pdf
# Skipping... 211/240 ---> নেপোলিয়ান বোনাপার্ট -১ম ও ২য় খণ্ড একত্রে - দীনেন্দ্রকুমার রায়.pdf
# Skipping... 212/240 ---> নেপোলিয়ান বোনাপার্ট -১ম ও ২য় খণ্ড একত্রে - দীনেন্দ্রকুমার রায়.pdf
# Skipping... 213/240 ---> এই জীবনের সত্য.pdf
# Skipping... 214/240 ---> সাহিত্য দর্শন - সৌগত চট্টোপাধ্যায়.pdf
# Skipping... 215/240 ---> পাতঞ্জল দর্শন - পূর্ণচন্দ্র শর্ম্মা.pdf
# Skipping... 216/240 ---> জ্ঞানতত্ত্বদর্শন - জন্মেজয় ঘটক.pdf
# Skipping... 217/240 ---> জাতিদর্পণ বা নিত্যদর্শন - যোগাচার্য্য জ্ঞানানন্দ দেব.pdf
# Skipping... 218/240 ---> প্রাচীনকালে বঙ্গরমণীর সমুদ্র যাত্রা – নির্ম্মলচন্দ্র চৌধুরী.pdf
# Skipping... 245/270 ---> জীবন্ত কোষ পরিচিতি ও কার্যকারিতা – ইঞ্জিনিয়ার আজিজুল বারী.pdf
# Skipping... 246/270 ---> শিক্ষা চাকরি ও খেলা ১৭_২৩.pdf
# Skipping... 247/270 ---> কর্মক্ষেত্র ২৩০২.pdf
# Skipping... 248/270 ---> নতুন ছন্দ পরিক্রমা.pdf
# Skipping... 249/270 ---> রবিবাসরীয় ২০০২২২.pdf
# Skipping... 250/270 ---> কোয়ান্টাম ব্যায়াম ও সৌন্দর্য চর্চা.pdf
# Skipping... 251/270 ---> বাবার সঙ্গে দেখা.pdf
# Skipping... 252/270 ---> সৎপ্রসঙ্গ - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 253/270 ---> রাজা রামকৃষ্ণ - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 254/270 ---> চিত্রাবলি - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 255/285 ---> বঙ্গের ইতিহাস Stewart's Histoy Of Bengal - অনুঃ দুর্গাদাস লাহিড়ী.pdf
# Skipping... 256/285 ---> পৃথিবীর ইতিহাস ১ম খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 257/285 ---> পৃথিবীর ইতিহাস ২য় খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 258/285 ---> পৃথিবীর ইতিহাস ৩য় খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 259/285 ---> পৃথিবীর ইতিহাস ৪র্থ খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 260/285 ---> পৃথিবীর ইতিহাস ৫ম খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 261/285 ---> পৃথিবীর ইতিহাস ৬ষ্ঠ খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 262/285 ---> পৃথিবীর ইতিহাস ৭ম খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 263/285 ---> পৃথিবীর ইতিহাস ৮ম খণ্ড ভারতবর্ষ(প্রাচীন ভারতবর্ষ) - দুর্গাদাস লাহিড়ী.pdf
# Skipping... 264/285 ---> শ্রীপ্রেয়োভক্তিরসার্ণব ও শ্রীকৃষ্ণভক্তিরসকদম্ব - শ্রীহরিদাস দাস.pdf
# Skipping... 265/285 ---> গুপী গাইন বাঘা বাইন - উপেন্দ্রকিশোর রায়চৌধুরী.pdf
# Skipping... 266/285 ---> রবীন্দ্রকাব্যে আনন্দস্বরূপ – গোপেশচন্দ্র দত্ত.pdf
# Skipping... 267/285 ---> শ্রীবৈষ্ণবানন্দিনী - শ্রীবলদেব বিদ্যাভূষণ.pdf
# Skipping... 268/285 ---> বৈষ্ণব কবি রসখান (১৬১৫-১৬৬৫) – মাখনলাল রায়চৌধুরী শাস্ত্রী.pdf
# Skipping... 269/285 ---> শ্রীব্রহ্ম যামল -শ্রীচৈতন্য কল্প -(শ্রীশিব-পার্বতী সংলাপ).pdf
# Skipping... 270/300 ---> শ্রীমদ্ভাগবত সমীক্ষা - ডঃ অর্জুনসখা দাস.pdf
# Skipping... 271/300 ---> একটি করুণ কাহিনি – শৈলেন কুমার চট্টোপাধ্যায়.pdf
# Skipping... 272/300 ---> পুরুষ পরীক্ষা-বিদ্যাপতি.pdf
# Skipping... 273/300 ---> দেহ-ঘর - শ্যামাচরণ দে.pdf
# Skipping... 274/300 ---> বিধি প্রসাদ ১.pdf
# Skipping... 275/300 ---> মুক্তি-স্নান - প্রভাবতী দেবী সরস্বতী.pdf
# Skipping... 276/300 ---> সপ্ত সিন্ধু - হিরন্ময় ভট্টাচার্য.pdf
# Skipping... 305/330 ---> সাহারা - ললিতকুমার বন্দ্যোপাধ্যায়.pdf
# Skipping... 306/330 ---> স্পর্শের প্রভাব - ধীরেন্দ্র নারায়ণ রায়.pdf
# Skipping... 307/330 ---> শ্রদ্ধা নিবেদন লতা মঙ্গেশকর.pdf
# Skipping... 308/330 ---> শ্রদ্ধা নিবেদন সন্ধ্যা মুখোপাধ্যায়.pdf
# Skipping... 309/330 ---> বাপ্পি লাহিড়ী শ্রদ্ধাঞ্জলি.pdf
# Skipping... 310/330 ---> জবার বদলে কাল যমুনার বিয়ে.pdf
# Skipping... 311/330 ---> বাংলার বাউল - ক্ষিতিমোহন সেন.pdf
# Skipping... 312/330 ---> মোপাসাঁ রচনা সংগ্রহ ১.pdf
# Skipping... 313/330 ---> মোপাসাঁ রচনা সংগ্রহ ১.pdf
# Skipping... 316/345 ---> রোববার২০০২২২.pdf
# Skipping... 317/345 ---> রবিবারোয়ারি ২০০২২০২২.pdf
# Skipping... 318/345 ---> পেটফাটা১৮.pdf
# Skipping... 319/345 ---> রকমারি কমিকস.pdf
# Skipping... 320/345 ---> চাচা চৌধুরী আর আফলাতুন.pdf
# Skipping... 321/345 ---> চাচা চৌধুরী আর রাকার আক্রমণ.pdf
# Skipping... 322/345 ---> চাচা চৌধুরী আর রাকার চ্যালেঞ্জ.pdf
# Skipping... 323/345 ---> মাস্টারমাইন্ড.pdf
# Skipping... 324/345 ---> দানব.pdf
# Skipping... 325/345 ---> আত্মসমর্পণ যোগ.pdf
# Skipping... 326/345 ---> চাই সাম্রাজ্য অখণ্ড.pdf
# Skipping... 327/345 ---> জীবনানন্দ কবিতা সমগ্র.pdf
# Skipping... 328/345 ---> সংলাপ.pdf
# Skipping... 329/345 ---> দাম্পত্য.pdf
# Skipping... 330/360 ---> কিশোর ভৌতিক সমগ্র ২.pdf
# Skipping... 331/360 ---> কিশোর ভৌতিক সমগ্র৩.pdf
# Skipping... 332/360 ---> চাচা চৌধুরী টোকিওতে.pdf
# Skipping... 333/360 ---> বাঘখেকো শিয়ালের ছানা.pdf
# Skipping... 334/360 ---> গল্প সমগ্র - প্রবোধকুমার সান্যালpdf.pdf
# Skipping... 335/360 ---> গল্প সঞ্চয়ন - প্রবোধকুমার সান্যাল.pdf
# Skipping... 336/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩৩০ (অষ্টম ও নবম সংখ্যা).pdf
# Skipping... 337/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩৩০ (পঞ্চম ও ষষ্ঠ সংখ্যা).pdf
# Skipping... 338/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩৩০ (চতুর্থ সংখ্যা).pdf
# Skipping... 339/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩৩০ (১২ ও ১৩ সংখ্যা).pdf
# Skipping... 340/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩৩০ (সপ্তম সংখ্যা).pdf
# Skipping... 341/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩২৯ (প্রথম সংখ্যা).pdf
# Skipping... 342/360 ---> শ্রীশ্রীবিষ্ণুপ্রিয়া গৌরাঙ্গ পত্রিকা ১৩২৯ (দ্বিতীয় ও তৃতীয় সংখ্যা).pdf
# Skipping... 343/360 ---> পত্রিকা১৯০২২২.pdf
# Skipping... 344/360 ---> উপন্যাস সমগ্র - জীবনানন্দ দাশ.pdf
# Skipping... 345/375 ---> কারুবাসনা - জীবনানন্দ দাশ.pdf
# Skipping... 346/375 ---> প্রেমের কথা - ললিতকুমার বন্দ্যোপাধ্যায়.pdf
# Skipping... 347/375 ---> রূপ-বন্যা - রাধানাথ ঘোষ.pdf
# Skipping... 348/375 ---> মিলনমাধুরী - নারায়ণচন্দ্র ভট্টাচার্য্য.pdf
# Skipping... 349/375 ---> বিলাতী গুপ্তকথা বা ইঙ্গলণ্ডে ফরাসী দস্যু - পঞ্চানন রায়.pdf
# Skipping... 350/375 ---> শৈলজার কথা - মহেন্দ্রনাথ দাস.pdf
# Skipping... 351/375 ---> প্রসাদ - দেবীপ্রসন্ন রায়চৌধুরী.pdf
# Skipping... 352/375 ---> যমুনা ধারা - সরোজনাথ ঘোষ.pdf
# Skipping... 353/375 ---> সাত দিন - উপেন্দ্রনাথ গঙ্গোপাধ্যায়.pdf
# Skipping... 354/375 ---> সপ্তপর্ণী - মুক্তিকুমার আচার্য্য.pdf
# Skipping... 355/375 ---> সুন্দরী - বসন্তকুমার চট্টোপাধ্যায়.pdf
# Skipping... 356/375 ---> মানুষ - শিবরাম চক্রবর্তী.pdf
# Skipping... 357/375 ---> গোধূলি-লগ্ন - শৈলজানন্দ মুখোপাধ্যায়.pdf
# Skipping... 358/375 ---> শ্রীরামকৃষ্ণ ও গিরিশচন্দ্র.pdf
# Skipping... 359/375 ---> উৎস মানুষ ( জানুয়ারি, ২০১০).pdf
# Skipping... 360/390 ---> উৎস মানুষ (নভেম্বর, ২০০৯).pdf
# Skipping... 361/390 ---> উৎস মানুষ ( জুলাই, ২০০৯).pdf
# Skipping... 362/390 ---> উৎস মানুষ ( জানুয়ারি, ২০০৭).pdf
# Skipping... 363/390 ---> উৎস মানুষ (সেপ্টেম্বর, ২০১০).pdf
# Skipping... 364/390 ---> উৎস মানুষ ( জানুয়ারি, ২০১১).pdf
# Skipping... 365/390 ---> উৎস মানুষ ( এপ্রিল-জুন, ২০১২).pdf
# Skipping... 366/390 ---> উৎস মানুষ ( জুলাই-সেপ্টেম্বর, ২০১২).pdf
# Skipping... 367/390 ---> উৎস মানুষ ( এপ্রিল-জুন, ২০১১).pdf
# Skipping... 368/390 ---> উৎস মানুষ (অক্টোবর-ডিসেম্বর, ২০১২).pdf
# Skipping... 369/390 ---> উৎস মানুষ ( জুলাই-সেপ্টেম্বর, ২০১১).pdf
# Skipping... 370/390 ---> উৎস মানুষ (অক্টোবর-নভেম্বর, ২০১১).pdf
# Skipping... 371/390 ---> A Thousand Splendid Suns – Khaled Hosseini(1).pdf
# Skipping... 372/390 ---> বাংলাদেশের ইতিহাস .pdf
# Skipping... 373/390 ---> নীলকন্ঠ - দুলেন্দ্র ভৌমিক.pdf
# Skipping... 374/390 ---> কিশোর কাহিনি সমগ্র - দুলেন্দ্র ভৌমিক.pdf
# Skipping... 375/405 ---> কিশোর পুরাণ সমগ্র - রমারঞ্জন মুখোপাধ্যায়.pdf
# Skipping... 588/615 ---> আশুসম্বিদ্দায়িনী - উমেশচন্দ্র চট্টোপাধ্যায়.pdf
# Skipping... 589/615 ---> আনন্দলোক ২৭ জানুয়ারী ২০১৭.pdf
# Skipping... 590/615 ---> ইংরাজ শাসনের পূর্বে আমাদের শিক্ষা – যোগেন্দ্রনাথ চট্টোপাধ্যায়.pdf
# Skipping... 591/615 ---> আর্য্যসঙ্গীতে রস – তুলসীচরণ ঘোষ.pdf
# Skipping... 592/615 ---> জীববৈচিত্রে চুনো মাছ – সূর্য্যেন্দু দে.pdf
# Skipping... 593/615 ---> কাশ্যপবংশ ভাস্কর (পরিশিষ্ট) যজুর্ব্বেদীয় কাশ্যপ বংশাবলী – সীতানাথ সিদ্ধান্তবাগীশ সংগৃহীত.pdf
# Skipping... 594/615 ---> রোগের কারণ (এপিজেনেটিক্স) – কমলিনী ব্যানার্জী.pdf
# Skipping... 595/615 ---> লঙ্কা কাহিনি – শিবদাস ঘোষ.pdf
# Skipping... 596/615 ---> শতবর্ষের আলোকে অধ্যাপিকা টি এ সরস্বতী আম্মা – পূরবী মুখার্জ্জী.pdf
# Skipping... 597/615 ---> সপ্তদশ শতাব্দীর তিনখানি দলিল ও একটি গ্রামীক বিরোধের কাহিনী – সুকুমার সেন.pdf
# Skipping... 598/615 ---> আখের গুড়ে শালুকডাঁটা.pdf
# Skipping... 599/615 ---> এক অসাধারণ মেলবন্ধন – ভূপতি চক্রবর্তী.pdf
# Skipping... 600/630 ---> Madhuparni Bachai Galpo Sankhya.pdf
# Skipping... 601/630 ---> মারাত্মক.pdf
# Skipping... 602/630 ---> আবার ডোডো তাতাই.pdf
# Skipping... 603/630 ---> অন্দর মহলের মালঞ্চ – চন্দন মুখোপাধ্যায়.pdf
# Skipping... 604/630 ---> আহ্নিকতত্বমালা.pdf
# Skipping... 605/630 ---> শৈশবকালীন বৃদ্ধি ও বিকাশ.pdf
# Skipping... 606/630 ---> পৌরাণিক কাহিনী.pdf
# Skipping... 607/630 ---> শ্রীগৌরাঙ্গলীলামৃত.pdf
# Skipping... 608/630 ---> শান্তি - নবকৃষ্ণ ঘোষ.pdf
# Skipping... 609/630 ---> সুরের পরশ - দেবাচার্য.pdf
# Skipping... 610/630 ---> স্বর্ণবাই - নবকুমার দত্ত.pdf
# Skipping... 611/630 ---> বড় বাবু নাটক - সর্ব্বরঞ্জন বরাট.pdf
# Skipping... 612/630 ---> বেয়াই মশাই - নাটক -অমল রায়চৌধুরী.pdf
# Skipping... 613/630 ---> মসনদে মোঘল নাটক - অমল সরকার.pdf
# Skipping... 614/630 ---> যদুবংশধ্বংশ - নাটক রাজকৃষ্ণ রায়.pdf
# Skipping... 615/645 ---> ল-বাবু - দুর্গাদাস দে.pdf
# Skipping... 616/645 ---> লবন দৈত্য বধ - কিশোরীমোহন মৈত্রেয়.pdf
# Skipping... 617/645 ---> নেইলস হেনরিক আবেল (গণিতবিদ) – জয়দীপ ভট্টাচার্য.pdf
# Skipping... 653/675 ---> বিশ্ব-ভারত ২য় খণ্ড - তরুণ ভারত - রাধাকমল মুখোপাধ্যায়.pdf
# Skipping... 654/675 ---> বিশ্ব-ভারত ১ম খণ্ড - মনোময় ভারত - রাধাকমল মুখোপাধ্যায়.pdf
# Skipping... 655/675 ---> ছন্দাঞ্জলি - দুলাল সাঁতরা.pdf
# Skipping... 656/675 ---> বিপ্লবী বিবেকানন্দ নাটক - অমল সরকার.pdf
# Skipping... 657/675 ---> সাত নদী - নরেন্দ্রনাথ মুখোপাধ্যায়.pdf
# Skipping... 658/675 ---> কীর্তিযর্স্য - ভবতোষ দত্ত.pdf
# Skipping... 659/675 ---> আয়োজন - বিমল কর.pdf
# Skipping... 660/690 ---> গায়ে হলুদ - দীনেশ চন্দ্র সেন.pdf
# Skipping... 661/690 ---> কপালকুণ্ডলা-তত্ত্ব - ললিতকুমার বন্দ্যোপাধ্যায়.pdf
# Skipping... 662/690 ---> ননীদা নট আউট - মতি নন্দী.pdf
# Skipping... 664/690 ---> হট্টমালার দেশে.pdf
# Skipping... 665/690 ---> যা হয়েছে তাই ন্যায়.pdf
# Skipping... 666/690 ---> ভৌতিক অমনিবাস.pdf
# Skipping... 667/690 ---> সংস্কৃতসাহিত্যের পাখী ও তাহার নামতালিকা.pdf
# Skipping... 668/690 ---> ভিটামিন ডি কী ও কেন – সুনীতিকুমার মণ্ডল.pdf
# Skipping... 669/690 ---> অধ্যাপক অরবিন্দনাথ নসু – সুব্রত ঘোষ.pdf
# Skipping... 670/690 ---> বিজ্ঞানে নোবেল পুরস্কার ২০১৯ – গোপাল মণ্ডল.pdf
# Skipping... 671/690 ---> দ্বীপ জ্বলে পোকাদের গায়ে – অন্বেষা দে.pdf
# Skipping... 672/690 ---> রাজেন্দ্রলাল মিত্র – রমেশচন্দ্র মজুমদার.pdf
# Skipping... 673/690 ---> শিবাজি ও গুরু গোবিন্দ সিংহ - রবীন্দ্রনাথ ঠাকুর 1951.pdf
# Skipping... 674/690 ---> রবিশঙ্কর – কুনাল বসু.pdf
# Skipping... 675/705 ---> রোববার ০৬০২২২.pdf
# Skipping... 676/705 ---> রবিবাসরীয় ০৬০২২২.pdf
# Skipping... 677/705 ---> রবিবারোয়ারি ০৬০২২২.pdf
# Skipping... 678/705 ---> হাসির গল্পের সংকলন.pdf
# Skipping... 679/705 ---> এই নগরের পথে.pdf
# Skipping... 680/705 ---> জয়ল্যান্ড.pdf
# Skipping... 681/705 ---> রোগ ও স্বাস্থ্য সচেতনতা – নিতাই প্রামাণিক.pdf
# Skipping... 682/705 ---> বনের আসর.pdf
# Skipping... 683/705 ---> ভুতের গল্প সংকলন.pdf
# Skipping... 684/705 ---> ইজিপশিয়ান ট্রেজার.pdf
# Skipping... 685/705 ---> মোহেন-জো-দাড়ো ও প্রাচীন সিন্ধুতীরের সভ্যতা.pdf
# Skipping... 686/705 ---> মল্লরাজত্বে সঙ্গীতের সৃষ্টি ও প্রচার – সত্যকিঙ্কর বন্দ্যোপাধ্যায়.pdf
# Skipping... 711/735 ---> উদ্ভিদপ্রেমী এক চিত্রশিল্পীর কাহিনি – সৌম্যকান্তি জানা.pdf
# Skipping... 712/735 ---> আলেয়ার আলো.pdf
# Skipping... 713/735 ---> হারানো নগরী.pdf
# Skipping... 714/735 ---> জীবন্ত পাতালপুরী.pdf
# Skipping... 715/735 ---> ট্যারাকিমোর ফাঁদে.pdf
# Skipping... 716/735 ---> রক্ষাকারী বেতাল.pdf
# Skipping... 717/735 ---> বাহাদুর ও কুং ফু দস্যুরা.pdf
# Skipping... 718/735 ---> চলমান অশরীরী উড়ন্ত দস্যু.pdf
# Skipping... 719/735 ---> দেবীপ্রসাদ এবং সত্যেন্দ্রনাথ (সান্নিধ্য ও সম্পর্ক) – অরুণাভ মিশ্র.pdf
# Skipping... 720/750 ---> তীর্থে তীর্থে দক্ষিণ ভারত – সুবল দত্ত.pdf
# Skipping... 721/750 ---> জ্যামিতিবিদ অধ্যাপক এম সি চাকী – সনাতন কোলে.pdf
# Skipping... 722/750 ---> ছত্রাকবিদ অঞ্জলি রায় – সায়ন্তন যশ.pdf
# Skipping... 723/750 ---> ইউনানি চিকিৎসা পদ্ধতি – সুমন্ত ঘোষ.pdf
# Skipping... 724/750 ---> অধ্যাপক শান্তিরঞ্জন পালিত – রাজর্ষি ঘোষ.pdf
# Skipping... 725/750 ---> মরুপিরানহা.pdf
# Skipping... 726/750 ---> আমি এবং কয়েকটি প্রজাপতি - হুমায়ুন আহমেদ.pdf
# Skipping... 727/750 ---> তেঁতুল পাতার গল্প.pdf
# Skipping... 728/750 ---> খুনি ম্যাজিক.pdf
# Skipping... 729/750 ---> অলৌকিক সৈকত.pdf
# Skipping... 730/750 ---> আটখানা পাটখানা.pdf
# Skipping... 731/750 ---> অন্ধকারে চিতা -২.pdf
# Skipping... 732/750 ---> কষ্ট.pdf
# Skipping... 733/750 ---> শ্রদ্ধেয় রাজধানী.pdf
# Skipping... 734/750 ---> প্যারাডাইস লস্ট.pdf
# Skipping... 735/765 ---> বাংলার নবজাগরণে এক বিস্মৃত পুরুষ অক্ষয়কুমার দত্ত – সরোজকুমার রায়.pdf
# Skipping... 736/765 ---> পাকস্থলী ক্যান্সারের ঝুঁকি কমান - শঙ্করকুমার নাথ.pdf
# Skipping... 737/765 ---> কাঁদানে গ্যাস শতবর্ষ পার করল – অমিতকৃষ্ণ দে.pdf
# Skipping... 738/765 ---> যুক্তিবাদী মুক্তচিন্তক অক্ষয়কুমার দত্ত – শতাব্দী দাশ.pdf
# Skipping... 739/765 ---> প্রহ্লাদ চুনীলাল বৈদ্য এক উজ্জ্বল জ্যোতির্পদার্থবিদ – ইন্দ্রজিৎ ঘোষ.pdf
# Skipping... 740/765 ---> বাংলায় বিজ্ঞানের পরিভাষা ও অক্ষয় কুমার দত্ত – মানস প্রতিম দাস.pdf
# Skipping... 741/765 ---> বিভা চৌধুরী এক বিস্মৃতপ্রায় বাঙালি মহিলা বিজ্ঞানী – ধ্রুবজ্যোতি চট্টোপাধ্যায়.pdf
# Skipping... 742/765 ---> সময়, আইনস্টাইন ও গোডেল – জনরঞ্জন গোস্বামী.pdf
# Skipping... 743/765 ---> অক্সিজেনের অভাব শরীর মানিয়ে নেয় – সিদ্ধার্থ জোয়ারদার.pdf
# Skipping... 744/765 ---> ভারতবর্ষীয় উপাসক সম্প্রদায় ও বিজ্ঞান সাহিত্যের অক্ষয়কুমার দত্ত – ভোলানাথ দত্ত.pdf
# Skipping... 745/765 ---> নোভেল করোনা ভাইরাস ঘটিত অতমারী – অরূপ রায়.pdf
# Skipping... 746/765 ---> কান্নার নেপথ্যে (শারীরবিজ্ঞানের দৃষ্টিতে) - কৃষ্ণা রায়.pdf
# Skipping... 747/765 ---> ভারত বিচিত্রা ১১১৩.pdf
# Skipping... 748/765 ---> বিজ্ঞানাচার্য সত্যেন্দ্রনাথ ও গণিত – সত্যবাচী সর.pdf
# Skipping... 749/765 ---> রসায়নবিজ্ঞানী কৃষ্ণকামিনী রোহাৎগী মুখার্জ্জী – শুভেন্দু চট্টোপাধ্যায়.pdf
# Skipping... 750/780 ---> সার্ধশতবর্ষে বিজ্ঞান লেখক জগদানন্দ রায়- দীপককুমার দাঁ.pdf
# Skipping... 751/780 ---> বাংলা ভাষাবোধের পথিকৃৎ অক্ষয়কুমার দত্ত – কমলবিকাশ বন্দ্যোপাধ্যায়.pdf
# Skipping... 752/780 ---> অচেনা এক ভারতীয় বিজ্ঞানী (ডঃ ইয়েল্লাপ্রগাদা সুব্বারাও) – সৌমিত্র কুমার চৌধুরী.pdf
# Skipping... 753/780 ---> ভারতে টিকা ব্যবহারের ইতিহাস – মানস প্রতিম দাস.pdf
# Skipping... 754/780 ---> বড্ড সরু গলা, লতাকে ফিরিয়ে দিয়েছিলেন মুম্বইয়ের বাঙালি প্রযোজক.pdf
# Skipping... 755/780 ---> বিশ্বজয়ের পর কপিলদের পুরস্কৃত করতে অনুষ্ঠান করেছিলেন ক্রিকেটভক্ত লতা.pdf
# Skipping... 756/780 ---> গান শুনে কেঁদে ফেলেছিলেন নেহরুও, ভরা সভায় তখনও লতা গেয়েই চলেছেন.pdf
# Skipping... 757/780 ---> ইসসা ভ্যালি.pdf
# Skipping... 758/780 ---> হাউ টু এনরিচ ইওর ম্যারেজ অ্যান্ড ইওর লাইফ.pdf
# Skipping... 759/780 ---> অন্ধকারে চিতা -১.pdf
# Skipping... 760/780 ---> পত্রিকা০৫০২২২.pdf
# Skipping... 761/780 ---> পড়লে ভয় পাবেন নমুনা কপি.pdf
# Skipping... 763/780 ---> শিবরাম চক্রবর্তী ও ভাষা বনাম সংখ্যা – ভূপতি চক্রবর্তী.pdf
# Skipping... 764/780 ---> বুনো ঘোড়ার নেপথ্য কাহিনি – শৈবালকুমার গুহ.pdf
# Skipping... 765/795 ---> জোসেফ ব্যাঙ্কস এবং ভারতে ন্যাচারাল হিস্ট্রি চর্চা – অপরাজিত বসু.pdf
# Skipping... 766/795 ---> কোমল গণনা – দেবরঞ্জন সরকার.pdf
# Skipping... 767/795 ---> মৌমাছি মৌমাছি কোথা যাও নাচিনাচি – শশধর বিশ্বাস.pdf
# Skipping... 768/795 ---> প্রাকৃতিক কাজ ও কৃষিকাজ – অভিনন্দন সেনগুপ্ত.pdf
# Skipping... 769/795 ---> বঙ্গোপসাগরে সাইক্লোনের নাম – শ্রীকুমার মিত্র.pdf
# Skipping... 770/795 ---> বিজ্ঞানী দেবেন্দ্রমোহন বোস – সুশ্বেতা বিশ্বাস (সেন).pdf
# Skipping... 771/795 ---> মোরগছানা - কার্ণেই চুকোভস্কি.pdf
# Skipping... 772/795 ---> ব্যাক্টেরিয়ার জৈব আস্তরণ – স্বর্ণাভ চৌধুরী.pdf
# Skipping... 773/795 ---> ক্রন্দনে করুণ - শিশিরকুমার চট্টোপাধ্যায়.pdf
# Skipping... 774/795 ---> চিতোর গৌরব - পূর্ণচন্দ্র কবিরঞ্জন.pdf
# Skipping... 775/795 ---> চিতোর লক্ষী - ব্রজেন্দ্রকুমার দে.pdf
# Skipping... 776/795 ---> তূণীর - কুমুদরঞ্জন মল্লিক.pdf
# Skipping... 777/795 ---> দীর্ঘ পর্যটনে - বিপ্লব বিশ্বাস.pdf
# Skipping... 778/795 ---> বাণী - অক্ষয়কুমার মৈত্রেয়.pdf
# Skipping... 779/795 ---> বাসন্তী - বিমল বোস.pdf
# Skipping... 780/810 ---> বিদর্ভ-নন্দিনী - গোবর্ধন শীল.pdf
# Skipping... 781/810 ---> মাদল - দীনেশচন্দ্র সেন.pdf
# Skipping... 782/810 ---> সারথি শ্রীকৃষ্ণ - মহেন্দ্রনাথ গুপ্ত.pdf
# ...
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5686, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5687, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5688, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5689, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5690, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5691, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5692, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5693, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5694, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5695, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5696, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5697, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5698, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5699, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
# ***** ERROR at 5700, date: May 10, 2021 at 4:40 PM: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01009943+2595139]
# 	Ordinal0 [0x00F9C9F1+2148849]
# 	Ordinal0 [0x00E94528+1066280]
# 	Ordinal0 [0x00E96E04+1076740]
# 	Ordinal0 [0x00E96CBE+1076414]
# 	Ordinal0 [0x00E96F50+1077072]
# 	Ordinal0 [0x00EBC920+1231136]
# 	Ordinal0 [0x00EDB9EC+1358316]
# 	Ordinal0 [0x00EB7474+1209460]
# 	Ordinal0 [0x00EDBC04+1358852]
# 	Ordinal0 [0x00EEBAF2+1424114]
# 	Ordinal0 [0x00EDB806+1357830]
# 	Ordinal0 [0x00EB6086+1204358]
# 	Ordinal0 [0x00EB6F96+1208214]
# 	GetHandleVerifier [0x011AB232+1658114]
# 	GetHandleVerifier [0x0126312C+2411516]
# 	GetHandleVerifier [0x0109F261+560433]
# 	GetHandleVerifier [0x0109E366+556598]
# 	Ordinal0 [0x00FA286B+2173035]
# 	Ordinal0 [0x00FA75F8+2192888]
# 	Ordinal0 [0x00FA76E5+2193125]
# 	Ordinal0 [0x00FB11FC+2232828]
# 	BaseThreadInitThunk [0x76D96739+25]
# 	RtlGetFullPathName_UEx [0x77CC8E7F+1215]
# 	RtlGetFullPathName_UEx [0x77CC8E4D+1165]
#  *****
#
# Completed. Total scrapped file: 5574
